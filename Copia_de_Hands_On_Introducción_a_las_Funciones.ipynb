# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/19WfNFwr8eu0YK3MGQh4RBczbKfbcqvgI?usp=sharing).

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función
print ("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función

len([1, 2 , 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función

sorted([5, 2, 4, 1, 3])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función

round(3.141529, 3)
# Out:
# 3.142

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función
min([5,7,3,6,1])
# Out:
# 1

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función
num = input ("Ingresa un número: ")

def cuadrado(numero):
  return numero ** 2

cuadrado(int(num))
# Out:
# Ingresa un número: 6
# 36

# %%
numa = input ("Ingresa un número a: ")
numb = input ("Ingresa un número b: ")

def cuadradobin (numa, numb):
  output = numa**2 + 2*numa*numb + numb**2
  return output

cuadradobin(int(numa), int(numb))
# Out:
# Ingresa un número a: 4
# Ingresa un número b: 5
# 81

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función

num = int(input ("Ingresa un número: "))

def par(numero):
  if numero % 2 == 0:
    print("El número es par")
  else:
    print("El número es impar")

par(num)
# Out:
# Ingresa un número: 8
# El número es par

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función

num = int(input ("Ingresa un número: "))

def factorial(numero):
  if numero == 0:
    return 1
  else:
    return numero * factorial(numero -1)

factorial(num)
# Out:
# Ingresa un número: 3
# 6

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas
lista_a = [1, 2]
lista_b = [3, 4, 5]

# %%
# difinir función

def unir_listas(lista1, lista2):
  lista_unida = lista1 + lista2
  return lista_unida

unir_listas(lista_a, lista_b)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario

diccionario = {'México' : 'Toluca', 'Nuevo León' : 'Monterrey', 'Jalisco' : 'Guadalajara', 'Puebla' : 'Puebla'}

diccionario
# Out:
# {'México': 'Toluca',
#  'Nuevo León': 'Monterrey',
#  'Jalisco': 'Guadalajara',
#  'Puebla': 'Puebla'}

# %%
# difinir función

clave = input ("Ingresa el nombre del estado: ")

def buscar(diccionario, clave):
  if clave in diccionario:
    return diccionario.get(clave)
  else:
    return 'No se encuentra'

print(buscar(diccionario, clave))
# Out:
# Ingresa el nombre del estado: Michocán
# No se encuentra

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda

agenda = [{'nombre':'Adriana', 'telefono':'443411989', 'correo':'actelleza@gmail.com'},
          {'nombre':'Lucy', 'telefono':'4431234567', 'correo':'lucy@gmail.com'},
          {'nombre':'Penny', 'telefono':'4437654321', 'correo':'penny@gmail.com'}]
agenda
# Out:
# [{'nombre': 'Adriana',
#   'telefono': '443411989',
#   'correo': 'actelleza@gmail.com'},
#  {'nombre': 'Lucy', 'telefono': '4431234567', 'correo': 'lucy@gmail.com'},
#  {'nombre': 'Penny', 'telefono': '4437654321', 'correo': 'penny@gmail.com'}]

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones

def menu_opciones():
  menu_opc='''
  **************************
  Menú CRUD - Agenda:
  **************************
  1. Ver agenda
  2. Crear contacto
  3. Consultar contacto
  4. Actualizar contacto
  5. Eliminar contacto
  6. Salir menú
  ***************************
'''
  print(menu_opc)

menu_opciones()
# Out:
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
from ast import Index
# Crear función mostrar agenda

def mostrar_agenda(agenda):

  print("\n------------------------------------------")
  print('Contactos en la agenda: ')
  print("------------------------------------------")
  for contacto in agenda:
    print(f"\nContacto {agenda.index(contacto)+1}:")
    print(f"nombre: {contacto['nombre']}")
    print(f"teléfono: {contacto['telefono']}")
    print(f"correo: {contacto['correo']}")
    print("------------------------------------------")

mostrar_agenda(agenda)
# Out:
# ------------------------------------------
# Contactos en la agenda:
# ------------------------------------------
#
# Contacto 1:
# nombre: Adriana
# teléfono: 443411989
# correo: actelleza@gmail.com
# ------------------------------------------
#
# Contacto 2:
# nombre: Lucy
# teléfono: 4431234567
# correo: lucy@gmail.com
# ------------------------------------------
#
# Contacto 3:
# nombre: Penny
# teléfono: 4437654321
# correo: penny@gmail.com
# ------------------------------------------

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
il.c

# %%
# Crear función crear contacto

def crear_contacto():
  print("\n------------------------------------------")
  print("Ingresa los datos del contacto a crear ")
  print("------------------------------------------\n")

  contacto={'nombre': input('Ingresa el nombre: '),
            'telefono': input('Ingresa el teléfono: '),
            'correo': input('Ingresa el correo: ')}

  agenda.append(contacto)

  print("\n------------------------------------------")
  print("Contacto creado con éxito ")
  print("------------------------------------------\n")

crear_contacto()
# Out:
# ------------------------------------------
# Ingresa los datos del contacto a crear
# ------------------------------------------
#
# Ingresa el nombre: Rally
# Ingresa el teléfono: 4430987654
# Ingresa el correo: rally@gmail.com
#
# ------------------------------------------
# Contacto creado con éxito
# ------------------------------------------

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto

def consultar_contacto(agenda):
  bcontacto = False
  print("\n---------------------------------------------------------")
  nombre = input("Ingresa el nombre del contacto a consultar: ")
  print("---------------------------------------------------------")
  for contacto in agenda:
    if contacto['nombre'] == nombre:
      bcontacto = True
      indice = agenda.index(contacto)
      break

  if bcontacto == True:

    print(f"\nContacto encontrado: {nombre} en el indice {indice}\n")
    print(agenda[indice])
    print("\n---------------------------------------------------------")
  else:
    print("\nContacto no encontrado")
    print("---------------------------------------------------------")


consultar_contacto(agenda)
# Out:
# ---------------------------------------------------------
# Ingresa el nombre del contacto a consultar: rally
# ---------------------------------------------------------
#
# Contacto no encontrado
# ---------------------------------------------------------

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto

def menu_actualizar():
  menu_actualizar = '''
  ==============================
  Menú actualizar contacto:
  ==============================

  1. Actualizar nombre
  2. Actualizar teléfono
  3. Actualizar correo
  4. Salir del menú
  ==============================
'''
  print(menu_actualizar)


menu_actualizar()
# Out:
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto

def consultar_contacto_act(agenda):
  bcontacto = False
  indice = 0
  print("\n---------------------------------------------------------")
  nombre = input("Ingresa el nombre del contacto a actualizar: ")
  print("---------------------------------------------------------")

  for contacto in agenda:
    if contacto['nombre'] == nombre:
      bcontacto = True
      indice = agenda.index(contacto)+1
      break

  if bcontacto == True:
    print(f"\nContacto a actualizar encontrado: {nombre} en el indice {indice-1}\n")
    print(agenda[indice-1])
    print("---------------------------------------------------------\n")

  else:
    print("\nContacto no encontrado")
    print("---------------------------------------------------------\n")



  return indice



consultar_contacto_act(agenda)
# Out:
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally en el indice 3
#
# {'nombre': 'Rally', 'telefono': '4430987654', 'correo': 'rally@gmail.com'}
# ---------------------------------------------------------
# 4

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto

def actualizar_nombre(agenda):

  ind=consultar_contacto_act(agenda)

  if ind != 0:
    nuevo_nombre = input("Ingresa el nuevo nombre: ")
    print("---------------------------------------------------------")
    agenda[ind-1]['nombre'] = nuevo_nombre
    print("\n Contacto actualizado: \n")

    print(agenda[ind-1])
    print("---------------------------------------------------------\n")

actualizar_nombre(agenda)
# Out:
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally en el indice 3
#
# {'nombre': 'Rally', 'telefono': '4438765432', 'correo': 'rally@gmail.com'}
# ---------------------------------------------------------
#
# Ingresa el nuevo nombre: Rally1
# ---------------------------------------------------------
#
#  Contacto actualizado:
#
# {'nombre': 'Rally1', 'telefono': '4438765432', 'correo': 'rally@gmail.com'}
# ---------------------------------------------------------

# %%
# Crear función actualizar telefono para actualizar contacto

def actualizar_telefono(agenda):

  ind=consultar_contacto_act(agenda)

  if ind != 0:
    nuevo_telefono = input("\n Ingresa el nuevo teléfono: ")
    print("---------------------------------------------------------")
    agenda[ind-1]['telefono'] = nuevo_telefono
    print("\n Contacto actualizado: \n")

    print(agenda[ind-1])
    print("---------------------------------------------------------")


actualizar_telefono(agenda)
# Out:
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally1
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally1 en el indice 3
#
# {'nombre': 'Rally1', 'telefono': '4438765432', 'correo': 'rally@gmail.com'}
# ---------------------------------------------------------
#
#
#  Ingresa el nuevo teléfono: 4431234
# ---------------------------------------------------------
#
#  Contacto actualizado:
#
# {'nombre': 'Rally1', 'telefono': '4431234', 'correo': 'rally@gmail.com'}
# ---------------------------------------------------------

# %%
# Crear función actualizar correo para actualizar contacto

def actualizar_correo(agenda):

  ind=consultar_contacto_act(agenda)

  if ind != 0:
    nuevo_correo = input("\n Ingresa el nuevo correo: ")
    print("---------------------------------------------------------")
    agenda[ind-1]['correo'] = nuevo_correo
    print("\n Contacto actualizado: \n")

    print(agenda[ind-1])
    print("---------------------------------------------------------")

actualizar_correo(agenda)
# Out:
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally1
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally1 en el indice 3
#
# {'nombre': 'Rally1', 'telefono': '4431234', 'correo': 'rally1@gmail.com'}
# ---------------------------------------------------------
#
#
#  Ingresa el nuevo correo: rally@gmail.ocm
# ---------------------------------------------------------
#
#  Contacto actualizado:
#
# {'nombre': 'Rally1', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}
# ---------------------------------------------------------

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto

def actualizar_contacto(agenda):
  while True:
    menu_actualizar()
    print("---------------------------------------------------------")
    opcion = input("Ingresa una opción: ")
    if opcion == '1':
      actualizar_nombre(agenda)
    elif opcion == '2':
      actualizar_telefono(agenda)
    elif opcion == '3':
      actualizar_correo(agenda)
    elif opcion == '4':
      print("---------------------------------------------------------")
      print("\nSaliste del menú actualizar contacto")
      print("---------------------------------------------------------")
      break
    else:
      print("---------------------------------------------------------")
      print("\n Opción no encontrada")
      print("---------------------------------------------------------")



actualizar_contacto(agenda)
# Out:
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================
#
# ---------------------------------------------------------
# Ingresa una opción: 5
# ---------------------------------------------------------
#
#  Opción no encontrada
# ---------------------------------------------------------
#
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================
#
# ---------------------------------------------------------
# Ingresa una opción: 1
#
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally1
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally1 en el indice 3
#
# {'nombre': 'Rally1', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}
# ---------------------------------------------------------
#
# Ingresa el nuevo nombre: Rally
# ---------------------------------------------------------
#
#  Contacto actualizado:
#
# {'nombre': 'Rally', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}
# ---------------------------------------------------------
#
#
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================
#
# ---------------------------------------------------------
# Ingresa una opción: 4
# ---------------------------------------------------------
#
# Saliste del menú actualizar contacto
# ---------------------------------------------------------

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto

def eliminar_contacto(agenda):
  bcontacto = False
  print("---------------------------------------------------------")
  nombre = input("\nIngresa el nombre del contacto a eliminar: ")
  print("---------------------------------------------------------")
  for contacto in agenda:
    if contacto['nombre'] == nombre:
      bcontacto = True
      break

  if bcontacto == True:
    agenda.remove(contacto)
    print("\n Contacto eliminado: \n")
    print("---------------------------------------------------------")
  else:
    print("\nContacto no encontrado\n")
    print("---------------------------------------------------------")

  print(agenda)



eliminar_contacto(agenda)
# Out:
# ---------------------------------------------------------
#
# Ingresa el nombre del contacto a eliminar: Lucy
# ---------------------------------------------------------
#
#  Contacto eliminado:
#
# ---------------------------------------------------------
# [{'nombre': 'Adriana', 'telefono': '443411989', 'correo': 'actelleza@gmail.com'}, {'nombre': 'Penny', 'telefono': '4437654321', 'correo': 'penny@gmail.com'}, {'nombre': 'Rally', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}]

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda

def menu_agenda():
  while True:
    menu_opciones()
    print("---------------------------------------------------------")
    opcion = input("Ingresa una opción: ")
    print("---------------------------------------------------------")
    if opcion == '1':
      mostrar_agenda(agenda)
      print("\n")

    elif opcion == '2':
      crear_contacto()
      print("\n")

    elif opcion == '3':
      consultar_contacto(agenda)
      print("\n")

    elif opcion == '4':
      actualizar_contacto(agenda)
      print("\n")

    elif opcion == '5':
      eliminar_contacto(agenda)
      print("\n")

    elif opcion == '6':
      print("\nSaliste del menú agenda")
      print("---------------------------------------------------------")
      break

    else:
      print("\n Opción no encontrada")
      print("---------------------------------------------------------")

menu_agenda()
# Out:
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 1
# ---------------------------------------------------------
#
# ------------------------------------------
# Contactos en la agenda:
# ------------------------------------------
#
# Contacto 1:
# nombre: Adriana
# teléfono: 443411989
# correo: actelleza@gmail.com
# ------------------------------------------
#
# Contacto 2:
# nombre: Penny
# teléfono: 4437654321
# correo: penny@gmail.com
# ------------------------------------------
#
# Contacto 3:
# nombre: Rally
# teléfono: 4431234
# correo: rally@gmail.ocm
# ------------------------------------------
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 2
# ---------------------------------------------------------
#
# ------------------------------------------
# Ingresa los datos del contacto a crear
# ------------------------------------------
#
# Ingresa el nombre: Rally1
# Ingresa el teléfono: 4431234567
# Ingresa el correo: rally@gmail.com
#
# ------------------------------------------
# Contacto creado con éxito
# ------------------------------------------
#
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 3
# ---------------------------------------------------------
#
# ---------------------------------------------------------
# Ingresa el nombre del contacto a consultar: Lana
# ---------------------------------------------------------
#
# Contacto no encontrado
# ---------------------------------------------------------
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: Lucy
# ---------------------------------------------------------
#
#  Opción no encontrada
# ---------------------------------------------------------
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 3
# ---------------------------------------------------------
#
# ---------------------------------------------------------
# Ingresa el nombre del contacto a consultar: Lucy
# ---------------------------------------------------------
#
# Contacto no encontrado
# ---------------------------------------------------------
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 4
# ---------------------------------------------------------
#
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================
#
# ---------------------------------------------------------
# Ingresa una opción: 1
#
# ---------------------------------------------------------
# Ingresa el nombre del contacto a actualizar: Rally
# ---------------------------------------------------------
#
# Contacto a actualizar encontrado: Rally en el indice 2
#
# {'nombre': 'Rally', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}
# ---------------------------------------------------------
#
# Ingresa el nuevo nombre: Rally1
# ---------------------------------------------------------
#
#  Contacto actualizado:
#
# {'nombre': 'Rally1', 'telefono': '4431234', 'correo': 'rally@gmail.ocm'}
# ---------------------------------------------------------
#
#
#   ==============================
#   Menú actualizar contacto:
#   ==============================
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#   ==============================
#
# ---------------------------------------------------------
# Ingresa una opción: 4
# ---------------------------------------------------------
#
# Saliste del menú actualizar contacto
# ---------------------------------------------------------
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Ingresa el nombre del contacto a eliminar: Rally1
# ---------------------------------------------------------
#
#  Contacto eliminado:
#
# ---------------------------------------------------------
# [{'nombre': 'Adriana', 'telefono': '443411989', 'correo': 'actelleza@gmail.com'}, {'nombre': 'Penny', 'telefono': '4437654321', 'correo': 'penny@gmail.com'}, {'nombre': 'Rally1', 'telefono': '4431234567', 'correo': 'rally@gmail.com'}]
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Ingresa el nombre del contacto a eliminar: Rally1
# ---------------------------------------------------------
#
#  Contacto eliminado:
#
# ---------------------------------------------------------
# [{'nombre': 'Adriana', 'telefono': '443411989', 'correo': 'actelleza@gmail.com'}, {'nombre': 'Penny', 'telefono': '4437654321', 'correo': 'penny@gmail.com'}]
#
#
#
#   **************************
#   Menú CRUD - Agenda:
#   **************************
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#   ***************************
#
# ---------------------------------------------------------
# Ingresa una opción: 6
# ---------------------------------------------------------
#
# Saliste del menú agenda
# ---------------------------------------------------------
